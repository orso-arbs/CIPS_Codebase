# %%
import pandas as pd
import io
import re

# Set display options to show full column content
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)  # Avoid line wrapping
pd.set_option('display.max_rows', None)  # Optional: show all rows

# %%
# from:
'''
find /cluster/scratch/{orsob,doancea/orsoMT_doancea,aolareanu/orsoMT_aolareanu} \
  -type f \
  -printf '%u\t%M\t%h\t%f\n'
'''
# then use:
# cat states_list.tsv

raw_data = '''
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00005
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00012
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00017
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00011
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00045
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00047
doancea -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00034
doancea -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00041
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00006
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00009
doancea -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00042
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00048
doancea -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00031
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00008
doancea -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00043
doancea -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00036
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00004
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00026
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00030
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00014
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00028
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00027
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00010
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00013
doancea -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00033
doancea -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00040
doancea -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00038
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00022
doancea -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00037
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00015
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00029
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00007
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00024
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00020
doancea -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00032
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00050
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00049
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00001
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00025
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00046
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00023
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00016
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00018
doancea -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00039
doancea -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00044
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00021
doancea -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00035
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00003
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00019
doancea -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part1 po_s912k_post0.f00002
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00023.gz
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00005
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00012
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00011
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00018.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00019.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00017.gz
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00006
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00009
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00025.gz
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00008
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00004
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00014
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00016.gz
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00010
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00013
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00026.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00020.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00024.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00022.gz
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00007
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00001
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00015.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00021.gz
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00003
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part5 po_s912k_post0.f00002
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part3 po_s912k_post0.f00005
scleon  -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part3 po_s912k_post0.f00012
scleon  -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part3 po_s912k_post0.f00011
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part3 po_s912k_post0.f00006
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part3 po_s912k_post0.f00009
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part3 po_s912k_post0.f00008
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part3 po_s912k_post0.f00004
scleon  -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part3 po_s912k_post0.f00014
scleon  -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part3 po_s912k_post0.f00010
scleon  -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part3 po_s912k_post0.f00013
scleon  -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part3 po_s912k_post0.f00015
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part3 po_s912k_post0.f00007
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part3 po_s912k_post0.f00001
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part3 po_s912k_post0.f00003
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part3 po_s912k_post0.f00002
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part2 po_s912k_post0.f00005
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part2 po_s912k_post0.f00011
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part2 po_s912k_post0.f00006
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part2 po_s912k_post0.f00009
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part2 po_s912k_post0.f00008
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part2 po_s912k_post0.f00004
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part2 po_s912k_post0.f00010
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part2 po_s912k_post0.f00007
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part2 po_s912k_post0.f00001
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part2 po_s912k_post0.f00003
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part2 po_s912k_post0.f00002
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part4 po_s912k_post0.f00005
aolareanu       -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part4 po_s912k_post0.f00011
aolareanu       -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part4 po_s912k_post0.f00006
aolareanu       -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part4 po_s912k_post0.f00009
aolareanu       -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part4 po_s912k_post0.f00008
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part4 po_s912k_post0.f00004
aolareanu       -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part4 po_s912k_post0.f00010
aolareanu       -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part4 po_s912k_post0.f00007
scleon  -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part4 po_s912k_post0.f00001
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part4 po_s912k_post0.f00003
aolareanu       -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part4 po_s912k_post0.f00002
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00008.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00001.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00009.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00003.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00015.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00007.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00012.gz
cfrouzak        -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00020.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00004.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00013.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00002.gz
cfrouzak        -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00019.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00006.gz
cfrouzak        -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00022.gz
cfrouzak        -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00021.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00016.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00017.gz
cfrouzak        -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00018.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00010.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00005.gz
cfrouzak        -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00023.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00011.gz
orsob   -rwxrwxrwx      /cluster/scratch/orsob/orsoMT_orsob/A11_states/po_part6 po_Sphere_mid0.f00014.gz
orsob   -rw-r--r--      /cluster/scratch/orsob/orsoMT_orsob     all.visit
orsob   -rw-r--r--      /cluster/scratch/orsob/orsoMT_orsob/A11_all_part_examples       part1_f00048
orsob   -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_all_part_examples       part6_f00001
orsob   -rwxr-xr-x      /cluster/scratch/orsob/orsoMT_orsob/A11_all_part_examples       part5_f00001
orsob   -rw-r--r--      /cluster/scratch/orsob/orsoMT_orsob/A11_all_part_examples       part3_f00005
orsob   -rw-r--r--      /cluster/scratch/orsob/orsoMT_orsob/A11_all_part_examples       part4_f00005
orsob   -rw-r--r--      /cluster/scratch/orsob/orsoMT_orsob/A11_all_part_examples       part2_f00010
'''

# Convert the raw string into a pandas DataFrame with column names
df = pd.read_csv(io.StringIO(raw_data), sep='\s+', header=None, names=['owner', 'permissions', 'location', 'filename'])

# Filter out rows where 'filename' does not match 'po_s912k_post0' or 'po_Sphere_mid0'
# df = df[df['filename'].str.contains(r'po_s912k_post0|po_Sphere_mid0', case=False, na=False)]

# df = df.sort_values(by=[
#     'location',
#     'filename',
#     'owner',
#     ])

# filtered = []
# for line in raw_data.strip().splitlines():
#     parts = line.split()
#     if len(parts) >= 4:
#         path = parts[2]
#         if "part4" in path:
#             filtered.append(line)

# for line in filtered:
#     print(line)

# Check the columns of the DataFrame
print(df.columns)
display(df)
# Out:
# Index(['owner', 'permissions', 'location', 'filename'], dtype='object')
# <>:157: SyntaxWarning: invalid escape sequence '\s'
# <>:157: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\obs\AppData\Local\Temp\ipykernel_50888\3158989678.py:157: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(io.StringIO(raw_data), sep='\s+', header=None, names=['owner', 'permissions', 'location', 'filename'])
#          owner permissions  \
# 0      doancea  -rwxrwxrwx
# 1      doancea  -rwxrwxrwx
# 2      doancea  -rwxrwxrwx
# 3      doancea  -rwxrwxrwx
# 4      doancea  -rwxrwxrwx
# 5       scleon  -rwxrwxrwx
# 6      doancea  -rwxr-xr-x
# 7      doancea  -rwxr-xr-x
# 8      doancea  -rwxrwxrwx
# 9      doancea  -rwxrwxrwx
# 10     doancea  -rwxr-xr-x
# 11      scleon  -rwxrwxrwx
# 12     doancea  -rwxr-xr-x
# 13     doancea  -rwxrwxrwx
# 14     doancea  -rwxr-xr-x
# 15     doancea  -rwxr-xr-x
# 16     doancea  -rwxrwxrwx
# 17     doancea  -rwxrwxrwx
# ...
